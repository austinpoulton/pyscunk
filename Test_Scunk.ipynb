# %%
import pandas as pd
from datetime import datetime
from pyscunk import SplunkConnector, connect
import json

# %%
test_query = 'search index=session_summary  | table loginSessionId timestamp'
splunk_session = connect('admin', 'admin', host='localhost', port=8089, app='search')
print splunk_session._base_path

results =  splunk_session.search_retry(test_query, earliest=datetime(2017, 1, 1, 0, 0, 0), latest=datetime(2017,7,18,14,59,59))
results
# Out:
# https://localhost:8089/
# /Users/austin/anaconda/lib/python2.7/site-packages/urllib3/connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/austin/anaconda/lib/python2.7/site-packages/urllib3/connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
#                                   loginSessionId                    timestamp
# 0   session-7a2c696a-48ec-4f18-9b99-25cf00351eee  2017-05-25T06:22:50.616 UTC
# 1   session-154034ae-a74f-461d-b382-14b998eca445  2017-06-19T06:22:52.553 UTC
# 2   session-b2f0bdee-fcad-45f4-a311-2ea367c3ca55  2017-06-20T06:22:54.587 UTC
# ...

# %%
# Out:
#                                   loginSessionId                    timestamp
# 0   session-7a2c696a-48ec-4f18-9b99-25cf00351eee  2017-05-25T06:22:50.616 UTC
# 1   session-154034ae-a74f-461d-b382-14b998eca445  2017-06-19T06:22:52.553 UTC
# 2   session-b2f0bdee-fcad-45f4-a311-2ea367c3ca55  2017-06-20T06:22:54.587 UTC
# 3   session-b4fd7885-3aec-4573-a1bf-256ceb4949d5  2017-06-21T06:22:56.794 UTC
# 4   session-8e407906-3c82-4ded-8545-02c7ab04eada  2017-05-29T06:18:00.165 UTC
# 5   session-69887f5f-60f3-4774-a1e2-152438cbb072  2017-05-21T06:18:00.532 UTC
# 6   session-d6c444a0-7587-489e-a870-85958d128b29  2017-06-19T06:18:00.596 UTC
# 7   session-6e94555f-5525-4dd3-abc8-1846612f45b1  2017-06-20T06:18:01.516 UTC
# 8   session-b03b85d4-56c0-4819-a8c6-65ab4874bc6e  2017-06-21T06:18:01.529 UTC
# 9   session-f177fe46-de47-4363-aaa8-cd7d415e7921  2017-05-21T06:27:51.111 UTC
# 10  session-90a72116-0e45-43ae-82dd-18a738b8fcd1  2017-06-19T06:27:52.577 UTC
# ...

# %%
test_query1 = 'search index=session_summary  '
results1 =  splunk_session.query(test_query1, earliest=datetime(2017, 1, 1, 0, 0, 0), latest=datetime(2017,7,18,14,59,59))
results1
# Out:
# /Users/austin/anaconda/lib/python2.7/site-packages/urllib3/connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# ...

# %%
test_query2 = 'search index=session_summary  | table deviceIds.* login_time loginSessionId machineInfo.*'
results2 =  splunk_session.search_retry(test_query2, earliest=datetime(2017, 1, 1, 0, 0, 0), latest=datetime(2017,7,18,14,59,59))
results2
# Out:
# /Users/austin/anaconda/lib/python2.7/site-packages/urllib3/connectionpool.py:852: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
#                                     deviceIds.augurId  \
# 0   591e2a72dc750b46d9a07a7b0efbcc78a28a52e64e10c9...
# 1   45019911ae44a911d62e565cd86334eed9e6b0d943725c...
# 2   93fe90d94a8494393a241b40991f3d3adbd2138be5c7b2...
# 3   45019911ae44a911d62e565cd86334eed9e6b0d943725c...
# 4   20769bad737d32fbfbea6642c95330722b33f1d17e34f9...
# 5   725eaf53f5cd978a13c778ab34cea290c80f7b15830860...
# 6   62ac5229c67f5fdc0eeac8d1aa7e50058ecb985834969f...
# 7   45019911ae44a911d62e565cd86334eed9e6b0d943725c...
# 8   3f62d3e176195223d846bf787bbc0d02d32bc02330d967...
# 9   d91e031a59dfced259ec5b013ec459d86147455c6f2524...
# 10  d2ffb38c2e6f9c7cffa04fed1e5b3191a47da79fb752f7...
# ...
